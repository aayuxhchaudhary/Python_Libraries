# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.head())

# returns first 5 rows
# Out:
#     name  age  marks       city
# 0  Sahil   24     90      Delhi
# 1   Riya   22     85     Mumbai
# 2   Aman   23     88       Pune
# 3   Neha   21     92  Bangalore
# 4  Karan   25     78    Chennai

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\hp

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.head(2))
# Out:
#     name  age  marks    city
# 0  Sahil   24     90   Delhi
# 1   Riya   22     85  Mumbai

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.tail())
# Shows last rows.
# Out:
#     name  age  marks       city
# 2   Aman   23     88       Pune
# 3   Neha   21     92  Bangalore
# 4  Karan   25     78    Chennai
# 5  Priya   20     95     Jaipur
# 6  Arjun   24     81  Hyderabad

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.tail(3))
# Useful for checking end records.
# Out:
#     name  age  marks       city
# 4  Karan   25     78    Chennai
# 5  Priya   20     95     Jaipur
# 6  Arjun   24     81  Hyderabad

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")
print(df.shape)
# (rows, columns)
# Out:
# (7, 4)

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.columns)
# Out:
# Index(['name', 'age', 'marks', 'city'], dtype='object')

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.dtypes)
# Out:
# name     object
# age       int64
# marks     int64
# city     object
# dtype: object

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   age     7 non-null      int64
#  2   marks   7 non-null      int64
#  3   city    7 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 356.0+ bytes

# %%
# total rows
# non-null values
# datatypes
# memory usage

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.describe())
# Out:
#              age      marks
# count   7.000000   7.000000
# mean   22.714286  87.000000
# std     1.799471   6.055301
# min    20.000000  78.000000
# 25%    21.500000  83.000000
# 50%    23.000000  88.000000
# 75%    24.000000  91.000000
# max    25.000000  95.000000

# %%
# Shows:
# mean
# std
# min
# max

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.isnull())
# Out:
#     name    age  marks   city
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False  False

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.isnull().sum())
# Out:
# name     0
# age      0
# marks    0
# city     0
# dtype: int64

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.sample(2))#Random rows.
# Out:
#     name  age  marks   city
# 0  Sahil   24     90  Delhi
# 2   Aman   23     88   Pune

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(len(df))#Teach row count.
# Out:
# 7

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.head())
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.info())
print(df.describe())
# Out:
#     name  age  marks       city
# 0  Sahil   24     90      Delhi
# 1   Riya   22     85     Mumbai
# 2   Aman   23     88       Pune
# 3   Neha   21     92  Bangalore
# 4  Karan   25     78    Chennai
# (7, 4)
# Index(['name', 'age', 'marks', 'city'], dtype='object')
# name     object
# age       int64
# marks     int64
# city     object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   age     7 non-null      int64
#  2   marks   7 non-null      int64
#  3   city    7 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 356.0+ bytes
# None
#              age      marks
# count   7.000000   7.000000
# mean   22.714286  87.000000
# std     1.799471   6.055301
# min    20.000000  78.000000
# 25%    21.500000  83.000000
# 50%    23.000000  88.000000
# 75%    24.000000  91.000000
# ...
