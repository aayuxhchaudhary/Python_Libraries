# %% [markdown]
# ### import pandas as pd
#
# df = pd.read_json("students.json")
#
# print(df.head())
#
# # returns first 5 rows

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df)
# Out:
#     name  age  marks       city
# 0  Sahil   24     90      Delhi
# 1  Jahil   25     95      Delhi
# 2   Riya   22     85     Mumbai
# 3   Aman   23     88       Pune
# 4   Neha   21     92  Bangalore
# 5  Karan   25     78    Chennai
# 6  Priya   20     95     Jaipur
# 7  Arjun   24     81  Hyderabad

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.tail(0))
# Shows last rows.
# Out:
# Empty DataFrame
# Columns: [name, age, marks, city]
# Index: []

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.tail(3))
# Useful for checking end records.
# Out:
#     name  age  marks       city
# 4  Karan   25     78    Chennai
# 5  Priya   20     95     Jaipur
# 6  Arjun   24     81  Hyderabad

# %%
import pandas as pd

df = pd.read_json("students.json")
print(df.shape)
# (rows, columns)
# Out:
# (7, 4)

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.columns)
# Out:
# Index(['name', 'age', 'marks', 'city'], dtype='object')

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.dtypes)
# Out:
# name     object
# age       int64
# marks     int64
# city     object
# dtype: object

# %%
import pandas as pd

df = pd.read_json("students.json")

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    8 non-null      str
#  1   age     8 non-null      int64
#  2   marks   8 non-null      int64
#  3   city    8 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 476.0 bytes

# %%
# total rows
# non-null values
# datatypes
# memory usage

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.describe())
# Out:
#             age      marks
# count   8.00000   8.000000
# mean   23.00000  88.000000
# std     1.85164   6.279217
# min    20.00000  78.000000
# 25%    21.75000  84.000000
# 50%    23.50000  89.000000
# 75%    24.25000  92.750000
# max    25.00000  95.000000

# %%
# Shows:
# mean
# std
# min
# max

# %%
import pandas as pd

df = pd.read_json("C:/Users/hp/Pandas/students.json")

print(df.isnull())
# Out:
#     name    age  marks   city
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False
# 5  False  False  False  False
# 6  False  False  False  False

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.isnull().sum())
# Out:
# name     0
# age      0
# marks    0
# city     0
# dtype: int64

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.sample(2))
# Out:
#     name  age  marks     city
# 1  Jahil   25     95    Delhi
# 5  Karan   25     78  Chennai

# %%
import pandas as pd

df = pd.read_json("students.json")

print(len(df))#Teach row count.
# Out:
# 8

# %%
import pandas as pd

df = pd.read_json("students.json")

print(df.head())
print(df.shape)
print(df.columns)
print(df.dtypes)
print(df.info())
print(df.describe())
# Out:
#     name  age  marks       city
# 0  Sahil   24     90      Delhi
# 1  Jahil   25     95      Delhi
# 2   Riya   22     85     Mumbai
# 3   Aman   23     88       Pune
# 4   Neha   21     92  Bangalore
# (8, 4)
# Index(['name', 'age', 'marks', 'city'], dtype='str')
# name       str
# age      int64
# marks    int64
# city       str
# dtype: object
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    8 non-null      str
#  1   age     8 non-null      int64
#  2   marks   8 non-null      int64
#  3   city    8 non-null      str
# dtypes: int64(2), str(2)
# memory usage: 476.0 bytes
# None
#             age      marks
# count   8.00000   8.000000
# mean   23.00000  88.000000
# std     1.85164   6.279217
# min    20.00000  78.000000
# 25%    21.75000  84.000000
# 50%    23.50000  89.000000
# 75%    24.25000  92.750000
# max    25.00000  95.000000
