# %%
import pandas as pd

df = pd.read_json("student2.json")

print(df)
# Out:
#      name   age  marks     city
# 0   Sahil  24.0   75.0    Delhi
# 1    Riya   NaN   75.0   Mumbai
# 2    Aman  23.0    NaN     Pune
# 3    Neha  21.0   92.0     None
# 4   Karan   NaN   90.0  Chennai
# 5  Charan   NaN   90.0  Chennai
# 6   Taran   NaN   92.0  Chennai

# %%
df.fillna(0, inplace=True)

print(df)
# Out:
#      name   age  marks     city
# 0   Sahil  24.0   75.0    Delhi
# 1    Riya   0.0   75.0   Mumbai
# 2    Aman  23.0    0.0     Pune
# 3    Neha  21.0   92.0        0
# 4   Karan   0.0   90.0  Chennai
# 5  Charan   0.0   90.0  Chennai
# 6   Taran   0.0   92.0  Chennai

# %%
print(df.isnull().sum())

print(df)
# Out:
# name     0
# age      0
# marks    0
# city     0
# dtype: int64
#      name   age  marks     city
# 0   Sahil  24.0   75.0    Delhi
# 1    Riya   0.0   75.0   Mumbai
# 2    Aman  23.0    0.0     Pune
# 3    Neha  21.0   92.0        0
# 4   Karan   0.0   90.0  Chennai
# 5  Charan   0.0   90.0  Chennai
# 6   Taran   0.0   92.0  Chennai

# %%
print(df)
# Out:
#      name   age  marks     city
# 0   Sahil  24.0   75.0    Delhi
# 1    Riya   NaN   75.0   Mumbai
# 2    Aman  23.0    NaN     Pune
# 3    Neha  21.0   92.0     None
# 4   Karan   NaN   90.0  Chennai
# 5  Charan   NaN   90.0  Chennai
# 6   Taran   NaN   92.0  Chennai
